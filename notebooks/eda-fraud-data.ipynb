# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath('../'))

from src.data_preprocessing import load_data, clean_data, merge_with_ip
from src.feature_engineering import add_features
from src.visualization import (
    plot_class_distribution, 
    plot_univariate_analysis, 
    plot_bivariate_analysis, 
    plot_geographic_fraud
)

# %%
fraud_raw, ip_raw = load_data('../data/raw/Fraud_Data.csv', '../data/raw/IpAddress_to_Country.csv')
df = clean_data(fraud_raw)
df = merge_with_ip(df, ip_raw)
df = add_features(df)

# %%
print("--- Class Distribution Analysis ---")
plot_class_distribution(df)
# Out:
# --- Class Distribution Analysis ---
# /Users/mac/Documents/kaim/fraud-detection/src/visualization.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class', data=df, ax=ax[0], palette='viridis')

# %%
print("\n--- Univariate Analysis ---")
plot_univariate_analysis(df)
# Out:
# --- Univariate Analysis ---
# /Users/mac/Documents/kaim/fraud-detection/src/visualization.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='source', data=df, ax=axes[1, 0], palette='Set2')
# /Users/mac/Documents/kaim/fraud-detection/src/visualization.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='browser', data=df, ax=axes[1, 1], palette='Set3')

# %%
print("\n--- Bivariate Analysis ---")
plot_bivariate_analysis(df)
# Out:
# --- Bivariate Analysis ---
# /Users/mac/Documents/kaim/fraud-detection/src/visualization.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='age', data=df, palette='Set2')
# /Users/mac/Documents/kaim/fraud-detection/src/visualization.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='purchase_value', data=df, palette='Set3')

# %%
print("\n--- Geolocation Fraud Analysis ---")
plot_geographic_fraud(df)
# Out:
# --- Geolocation Fraud Analysis ---
